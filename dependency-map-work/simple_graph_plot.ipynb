# %% [markdown]
# Import required python modules
# source appropriate pyhton environment like: source /my_dev_env/dev_workspace/dev/bin/activate
# pip3 install jaal
# pip3 install dash
# pip3 install pandas

# %%
import pandas as pd
from jaal import Jaal
from jaal.datasets import load_got
#from dash import html as html
#from dash import dcc  as dcc
#from dash.dependencies import Input, Output, State

# %%
file_name = "csv/DependenciasBRCL.csv"
df =  pd.read_csv(file_name)

# %%
list(df)
# Out:
# ['from', 'to', 'weight']

# %%
df.head(500)
# Out:
#                 from              to  weight
# 0      BR-ADMIEXDMGR    54.68.97.123       1
# 1      BR-ADMIEXDMGR    54.68.97.123       3
# 2      BR-ADMIEXDMGR   192.168.81.11       1
# 3      BR-ADMIEXDMGR   192.168.81.10       1
# 4      BR-ADMIEXDMGR  44.225.240.147       2
# ..               ...             ...     ...
# 495  BR-ADMIEXJRE01P   64.39.104.113       5
# 496  BR-ADMIEXJRE01P   64.39.104.113       3
# 497  BR-ADMIEXJRE01P   23.222.252.70      33
# 498  BR-ADMIEXJRE01P  192.168.78.210   58218
# 499  BR-ADMIEXJRE01P  192.168.78.210     152
#
# [500 rows x 3 columns]

# %%
#Jaal(df).plot(port=8070)
Jaal(df).plot(vis_opts={'height': '600px', # change height
                                     'interaction':{'hover': True}, # turn on-off the hover 
                                    'physics':{'stabilization':{'iterations': 100}}})

#Jaal(df).plot(vis_opts={'height': '600px', # change height
#                                      'interaction':{'hover': True}, # turn on-off the hover 
#                                      'physics':{'enabled': False}})
#
# Links de los Datos https://visjs.github.io/vis-network/docs/network/physics.html#
# https://github.com/imohitmayank/jaal
# Out:
# Parsing the data...Done
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No trigger
