# %%
import pandas as pd
from jaal import Jaal
from jaal.datasets import load_got
from dash import html as html
#from dash import dcc  as dcc
#from dash.dependencies import Input, Output, State

# %%
sz_file_path = "csv/DependenciasBRCL.csv"
sz_file_csv = pd.read_csv(sz_file_path,usecols=['initiatingDeviceName','receivingDeviceName','receivingPort','connectionCount'],
                          header=0,
                        #dtype={'initiatingDeviceName': 'str', 'receivingDeviceName': 'str', 'receivingPort': int, 'connectionCount': int } 
                        )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 sz_file_path = "csv/DependenciasBRCL.csv"
# ----> 2 sz_file_csv = pd.read_csv(sz_file_path,usecols=['initiatingDeviceName','receivingDeviceName','receivingPort','connectionCount'],
#       3                           header=0,
#       4                         #dtype={'initiatingDeviceName': 'str', 'receivingDeviceName': 'str', 'receivingPort': int, 'connectionCount': int }
#       5                         )
#
# ...

# %%
df = sz_file_csv.rename(
    columns={
        "initiatingDeviceName": "from",
        "receivingDeviceName": "to",
        "connectionCount": "weight"
    }
)

# %% [markdown]
# A this point you must start the clenup strategies here
# Is possible to move forward, however the interactive plot will not be clear.
# You can remove:
# - Unscanned Devices
# - Infra communication: eg: Backup Server, Security Scans, Probes
# - Lower communication: create a numeric threashold

# %%
df_grouped = df.groupby(['from','to'], as_index=False)['weight'].sum()

# %%
len(df_grouped)

# %%
Jaal(df_grouped).plot(port=8085)
