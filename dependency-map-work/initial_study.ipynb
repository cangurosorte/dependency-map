# %% [markdown]
# Import required python modules
# source appropriate pyhton environment like: source /my_dev_env/dev_workspace/dev/bin/activate
# pip3 install jaal
# pip3 install dash
# pip3 install pandas

# %% [markdown]
# ## Initial import

# %%
import pandas as pd
from jaal import Jaal
from dash import html as html

# %% [markdown]
# ## Load csv base files

# %%
sz_file_path = "csv/sz_raw_dependencies.csv"

# %% [markdown]
# ## Variables

# %%
remove_string = "Unscanned Device"

# %% [markdown]
# ## Load CSV in Pandas Dataframe

# %%
sz_file_csv = pd.read_csv(sz_file_path,usecols=['initiatingDeviceName','receivingDeviceName','receivingPort','connectionCount'],
                          header=0,
                          encoding = "ISO-8859-1"
                        #dtype={'initiatingDeviceName': 'str', 'receivingDeviceName': 'str', 'receivingPort': int, 'connectionCount': int } 
                        )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sz_file_csv = pd.read_csv(sz_file_path,usecols=['initiatingDeviceName','receivingDeviceName','receivingPort','connectionCount'],
#       2                           header=0,
#       3                           encoding = "ISO-8859-1"
#       4                         #dtype={'initiatingDeviceName': 'str', 'receivingDeviceName': 'str', 'receivingPort': int, 'connectionCount': int }
#       5                         )
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:135, in CParserWrapper.__init__(self, src, **kwds)
#     131 assert self.orig_names is not None
#     132 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     133     self.orig_names
#     134 ):
# --> 135     self._validate_usecols_names(usecols, self.orig_names)
#     137 # error: Cannot determine type of 'names'
#     138 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     139     # error: Cannot determine type of 'names'
#
# File ~/dev_workspace/dev/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:866, in ParserBase._validate_usecols_names(self, usecols, names)
#     864 missing = [c for c in usecols if c not in names]
#     865 if len(missing) > 0:
# --> 866     raise ValueError(
#     867         f"Usecols do not match columns, columns expected but not found: "
#     868         f"{missing}"
#     869     )
#     871 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['initiatingDeviceName', 'receivingDeviceName', 'receivingPort', 'connectionCount']

# %%
df.head(5)
# Out:
#                     from            to weight
# 0                    BTG  L03331PAPP01  1,858
# 1               EbMl-env   W03900PMBX0     26
# 2    EbMl-env_0000000002   W03900PMBX0      7
# 3             EbObol-env   W03900PMBX0      2
# 4  EbObol-env_0000000002   W03900PMBX0      2

# %%
Jaal(df).plot(port=8071)
# Out:
# Parsing the data...Done
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8071/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No trigger
