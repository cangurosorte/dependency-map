# %% [markdown]
# Import required python modules
# source appropriate pyhton environment like: source /my_dev_env/dev_workspace/dev/bin/activate
# pip3 install jaal
# pip3 install dash
# pip3 install pandas

# %%
import pandas as pd
from jaal import Jaal
from jaal.datasets import load_got
#from dash import html as html
#from dash import dcc  as dcc
#from dash.dependencies import Input, Output, State

# %%
file_name = "csv/processed_dependency.csv"
df =  pd.read_csv(file_name)

# %%
list(df)
# Out:
# ['from', 'to', 'weight', 'appName']

# %%
df.head(5)
# Out:
#          from        to  weight appName
# 0       SRV20  SRVLX408     762   Green
# 1      SRV103  SRVBD197     615   Green
# 2      SRV103  SRVLX408     762   Green
# 3  SRVAPP1004  SRVLX408     762   Green
# 4  SRVAPP1005  SRVLX408     762   Green

# %%
Jaal(df).plot(port=8071)
# Out:
# Parsing the data...Done
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8071/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No trigger
# No trigger
# inside color edge appName
# Modifying edge size using  weight
# Modifying edge size using  weight
